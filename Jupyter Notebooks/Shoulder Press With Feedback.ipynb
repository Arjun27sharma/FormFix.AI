# %%
import cv2
import mediapipe as mp 
import numpy as np

mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
def calculateAngle(a,b,c):
    
    """
    Calculates the angle between three points in a 2D plane.

    :param a: A tuple or list containing the (x,y) coordinates of the first point.
    :type a: tuple or list of int or float
    :param b: A tuple or list containing the (x,y) coordinates of the second point.
    :type b: tuple or list of int or float
    :param c: A tuple or list containing the (x,y) coordinates of the third point.
    :type c: tuple or list of int or float
    :return: The angle in degrees between the line segments connecting point a to b and point b to c.
    :rtype: float
    """
    
    a = np.array(a) #First
    b = np.array(b) #Second
    c = np.array(c) #Third
    
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360 - angle
    
    return angle

# %%
#Camera and it's Resolution

cap = cv2.VideoCapture(0)

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

#Curl Counter Variables

counter = 0
stage = None

# Setup A Meadiapipe Instance

with mp_pose.Pose(min_detection_confidence = 0.55, min_tracking_confidence = 0.55) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
    #Detection and Rendering
        
        #Flipping the Image (To correct lateral inversion)
        
        frame = cv2.flip(frame, 1)
        
        #Recolour the Image to Mediapipe Format
        
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Make Detections
        
        results = pose.process(image)
        
        #Recolour the Image to cv2 Format
        
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        #Extract Landmarks
        
        try:
            landmarks = results.pose_landmarks.landmark
            #print(landmarks)
            
            #Get Coordinates
            
            shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            
            #Calculate Angle 
            
            shoulder_elbow_angle = calculateAngle(shoulder, elbow, wrist)
            
            #Visualise the angle
            
            cv2.putText(image, str(shoulder_elbow_angle),
                          tuple(np.multiply(elbow, [width,height]).astype(int)),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                        )
            
            #Curl Counter Logic
            
            if(counter != 0):
                if(shoulder_elbow_angle < 80):
                    cv2.putText(image, 'Too Low, Keep your arms InLine to your shoulder', 
                                  tuple(np.multiply([0.6,0.4], [width,height]).astype(int)),
                                      cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,255,255), 2, cv2.LINE_AA)
            if shoulder_elbow_angle < 80:
                stage = "Down"
            if shoulder_elbow_angle > 160 and stage == 'Down':
                stage = "Up"
                counter += 1
                #print(counter)
            
        except:
            pass
        
        #Render Curl Counter 
        
        #Setup Status Box
        
        cv2.rectangle(image, (0,0), (150,73), (245,117,16), -1)
        
        #Rep Data
        
        cv2.putText(image, "REPS", (15,20),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA
                   )
        cv2.putText(image, str(counter), (20,60),
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0,63,125), 2, cv2.LINE_AA
                   )

        #Stage Data
        
        cv2.putText(image, "STAGE", (75,20),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,0), 1, cv2.LINE_AA
                   )
        if (stage == 'Up'):
            cv2.putText(image, stage, (78,60),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0,63,125), 2, cv2.LINE_AA
                       )
        else:
            cv2.putText(image, stage, (60,55),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0,63,125), 2, cv2.LINE_AA
                       )
        
        
        #Render Detections
        
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color = (245,117,66), thickness = 2, circle_radius = 2),
                                 mp_drawing.DrawingSpec(color = (245,66,230), thickness = 2, circle_radius = 2)
                                 )
        
        #print(results)
        
        cv2.imshow("Mediapipe Feed", image)
        
        if(cv2.waitKey(10) & 0xFF == ord('q')):
            break
    
    cap.release()
    cv2.destroyAllWindows()
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# 1   HIToolbox                           0x000000019ff705c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x000000019ff70188 _ZN15MenuBarInstance14EnableAutoShowEv + 60
# 3   HIToolbox                           0x000000019fedd8bc _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1184
# 4   HIToolbox                           0x000000019ff70004 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 180
# 5   AppKit                              0x0000000199d66008 -[NSApplication _setPresentationOptions:instance:flags:] + 956
# 6   AppKit                              0x0000000199bfbbb0 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 404
# 7   CoreFoundation                      0x000000019681d570 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 148
# 8   CoreFoundation                      0x00000001968bb054 ___CFXRegistrationPost_block_invoke + 88
# 9   CoreFoundation                      0x00000001968baf9c _CFXRegistrationPost + 440
# 10  CoreFoundation                      0x00000001967eeb74 _CFXNotificationPost + 708
# 11  Foundation                          0x00000001976dc72c -[NSNotificationCenter postNotificationName:object:userInfo:] + 88
# 12  AppKit                              0x0000000199d6658c spacesNotificationHandler + 96
# 13  SkyLight                            0x000000019b4504dc _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 14  SkyLight                            0x000000019b44f0d8 CGSSnarfAndDispatchDatagrams + 808
# 15  SkyLight                            0x000000019b776a8c SLSGetNextEventRecordInternal + 344
# 16  SkyLight                            0x000000019b5785a4 SLEventCreateNextEvent + 16
# 17  HIToolbox                           0x000000019ff08b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 18  HIToolbox                           0x000000019ff08ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 19  CoreFoundation                      0x0000000196858420 __CFMachPortPerform + 260
# 20  CoreFoundation                      0x0000000196828fa8 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 21  CoreFoundation                      0x0000000196828ec8 __CFRunLoopDoSource1 + 520
# 22  CoreFoundation                      0x00000001968278b4 __CFRunLoopRun + 2264
# 23  CoreFoundation                      0x0000000196826888 CFRunLoopRunSpecific + 612
# 24  HIToolbox                           0x000000019fefbfa0 RunCurrentEventLoopInMode + 292
# 25  HIToolbox                           0x000000019fefbde4 ReceiveNextEventCommon + 672
# 26  HIToolbox                           0x000000019fefbb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 27  AppKit                              0x0000000199aa8424 _DPSNextEvent + 632
# 28  AppKit                              0x0000000199aa75b4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 29  cv2.abi3.so                         0x000000011d4ead2c cvWaitKey + 344
# 30  cv2.abi3.so                         0x000000011d4e4e64 _ZN2cv9waitKeyExEi + 168
# 31  cv2.abi3.so                         0x000000011d4e4f5c _ZN2cv7waitKeyEi + 48
# 32  cv2.abi3.so                         0x000000011caad8f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 33  Python                              0x0000000104f509f8 cfunction_call + 60
# 34  Python                              0x0000000104efce34 _PyObject_MakeTpCall + 128
# 35  Python                              0x0000000104ff60d4 _PyEval_EvalFrameDefault + 48228
# 36  Python                              0x0000000104fe977c PyEval_EvalCode + 280
# 37  Python                              0x0000000104fe426c builtin_exec + 432
# 38  Python                              0x0000000104ff7478 _PyEval_EvalFrameDefault + 53256
# 39  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 40  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 41  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 42  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 43  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 44  Python                              0x0000000104f16374 gen_send_ex + 36
# 45  Python                              0x0000000104f0b4dc method_vectorcall_O + 100
# 46  Python                              0x0000000104ff5da8 _PyEval_EvalFrameDefault + 47416
# 47  Python                              0x0000000104ffb404 _PyEval_Vector + 116
# 48  Python                              0x0000000104f00518 method_vectorcall + 272
# 49  Python                              0x0000000104efd8bc _PyVectorcall_Call + 116
# 50  Python                              0x0000000104ff81f0 _PyEval_EvalFrameDefault + 56704
# 51  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 52  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 53  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 54  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 55  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 56  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 57  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 58  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 59  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 60  _asyncio.cpython-311-darwin.so      0x000000010578049c task_step_impl + 440
# 61  _asyncio.cpython-311-darwin.so      0x0000000105780270 task_step + 52
# 62  _asyncio.cpython-311-darwin.so      0x0000000105780cf4 task_wakeup + 120
# 63  Python                              0x0000000104f51340 cfunction_vectorcall_O + 92
# 64  Python                              0x0000000105019428 _PyObject_VectorcallTstate.4592 + 96
# 65  Python                              0x00000001050192dc context_run + 92
# 66  Python                              0x0000000104f515ac cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 67  Python                              0x0000000104ff81f0 _PyEval_EvalFrameDefault + 56704
# 68  Python                              0x0000000104fe977c PyEval_EvalCode + 280
# 69  Python                              0x0000000104fe426c builtin_exec + 432
# 70  Python                              0x0000000104f515ac cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 71  Python                              0x0000000104ff5da8 _PyEval_EvalFrameDefault + 47416
# 72  Python                              0x0000000104ffb404 _PyEval_Vector + 116
# 73  Python                              0x000000010506dc58 pymain_run_module + 208
# 74  Python                              0x000000010506d76c Py_RunMain + 896
# 75  Python                              0x000000010506eb58 Py_BytesMain + 40
# 76  dyld                                0x000000019641fe50 start + 2544
# 1   HIToolbox                           0x000000019fefb90c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x000000019ff3a478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x000000019b4504dc _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000019b44f0d8 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x000000019b776a8c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x000000019b5785a4 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x000000019ff08b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x000000019ff08ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x0000000196858420 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x0000000196828fa8 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x0000000196828ec8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x00000001968278b4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x0000000196826888 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x000000019fefbfa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x000000019fefbc30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x000000019fefbb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x0000000199aa8424 _DPSNextEvent + 632
# 18  AppKit                              0x0000000199aa75b4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x000000011d4ead2c cvWaitKey + 344
# 20  cv2.abi3.so                         0x000000011d4e4e64 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x000000011d4e4f5c _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x000000011caad8f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  Python                              0x0000000104f509f8 cfunction_call + 60
# 24  Python                              0x0000000104efce34 _PyObject_MakeTpCall + 128
# 25  Python                              0x0000000104ff60d4 _PyEval_EvalFrameDefault + 48228
# 26  Python                              0x0000000104fe977c PyEval_EvalCode + 280
# 27  Python                              0x0000000104fe426c builtin_exec + 432
# 28  Python                              0x0000000104ff7478 _PyEval_EvalFrameDefault + 53256
# 29  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 30  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 31  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 32  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 33  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 34  Python                              0x0000000104f16374 gen_send_ex + 36
# 35  Python                              0x0000000104f0b4dc method_vectorcall_O + 100
# 36  Python                              0x0000000104ff5da8 _PyEval_EvalFrameDefault + 47416
# 37  Python                              0x0000000104ffb404 _PyEval_Vector + 116
# 38  Python                              0x0000000104f00518 method_vectorcall + 272
# 39  Python                              0x0000000104efd8bc _PyVectorcall_Call + 116
# 40  Python                              0x0000000104ff81f0 _PyEval_EvalFrameDefault + 56704
# 41  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 42  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 43  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 44  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 45  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 46  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 47  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 48  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 49  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 50  _asyncio.cpython-311-darwin.so      0x000000010578049c task_step_impl + 440
# 51  _asyncio.cpython-311-darwin.so      0x0000000105780270 task_step + 52
# 52  _asyncio.cpython-311-darwin.so      0x0000000105780cf4 task_wakeup + 120
# 53  Python                              0x0000000104f51340 cfunction_vectorcall_O + 92
# 54  Python                              0x0000000105019428 _PyObject_VectorcallTstate.4592 + 96
# 55  Python                              0x00000001050192dc context_run + 92
# 56  Python                              0x0000000104f515ac cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 57  Python                              0x0000000104ff81f0 _PyEval_EvalFrameDefault + 56704
# 58  Python                              0x0000000104fe977c PyEval_EvalCode + 280
# 59  Python                              0x0000000104fe426c builtin_exec + 432
# 60  Python                              0x0000000104f515ac cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  Python                              0x0000000104ff5da8 _PyEval_EvalFrameDefault + 47416
# 62  Python                              0x0000000104ffb404 _PyEval_Vector + 116
# 63  Python                              0x000000010506dc58 pymain_run_module + 208
# 64  Python                              0x000000010506d76c Py_RunMain + 896
# 65  Python                              0x000000010506eb58 Py_BytesMain + 40
# 66  dyld                                0x000000019641fe50 start + 2544
# 1   HIToolbox                           0x000000019ff705c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x000000019ff3a478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x000000019b4504dc _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000019b44f0d8 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x000000019b776a8c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x000000019b5785a4 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x000000019ff08b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x000000019ff08ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x0000000196858420 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x0000000196828fa8 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x0000000196828ec8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x00000001968278b4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x0000000196826888 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x000000019fefbfa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x000000019fefbc30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x000000019fefbb2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x0000000199aa8424 _DPSNextEvent + 632
# 18  AppKit                              0x0000000199aa75b4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x000000011d4ead2c cvWaitKey + 344
# 20  cv2.abi3.so                         0x000000011d4e4e64 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x000000011d4e4f5c _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x000000011caad8f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  Python                              0x0000000104f509f8 cfunction_call + 60
# 24  Python                              0x0000000104efce34 _PyObject_MakeTpCall + 128
# 25  Python                              0x0000000104ff60d4 _PyEval_EvalFrameDefault + 48228
# 26  Python                              0x0000000104fe977c PyEval_EvalCode + 280
# 27  Python                              0x0000000104fe426c builtin_exec + 432
# 28  Python                              0x0000000104ff7478 _PyEval_EvalFrameDefault + 53256
# 29  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 30  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 31  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 32  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 33  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 34  Python                              0x0000000104f16374 gen_send_ex + 36
# 35  Python                              0x0000000104f0b4dc method_vectorcall_O + 100
# 36  Python                              0x0000000104ff5da8 _PyEval_EvalFrameDefault + 47416
# 37  Python                              0x0000000104ffb404 _PyEval_Vector + 116
# 38  Python                              0x0000000104f00518 method_vectorcall + 272
# 39  Python                              0x0000000104efd8bc _PyVectorcall_Call + 116
# 40  Python                              0x0000000104ff81f0 _PyEval_EvalFrameDefault + 56704
# 41  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 42  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 43  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 44  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 45  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 46  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 47  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 48  Python                              0x0000000104fed5f0 _PyEval_EvalFrameDefault + 12672
# 49  Python                              0x0000000104f171c8 gen_send_ex2 + 208
# 50  _asyncio.cpython-311-darwin.so      0x000000010578049c task_step_impl + 440
# 51  _asyncio.cpython-311-darwin.so      0x0000000105780270 task_step + 52
# 52  _asyncio.cpython-311-darwin.so      0x0000000105780cf4 task_wakeup + 120
# 53  Python                              0x0000000104f51340 cfunction_vectorcall_O + 92
# 54  Python                              0x0000000105019428 _PyObject_VectorcallTstate.4592 + 96
# 55  Python                              0x00000001050192dc context_run + 92
# 56  Python                              0x0000000104f515ac cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 57  Python                              0x0000000104ff81f0 _PyEval_EvalFrameDefault + 56704
# 58  Python                              0x0000000104fe977c PyEval_EvalCode + 280
# 59  Python                              0x0000000104fe426c builtin_exec + 432
# 60  Python                              0x0000000104f515ac cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 61  Python                              0x0000000104ff5da8 _PyEval_EvalFrameDefault + 47416
# 62  Python                              0x0000000104ffb404 _PyEval_Vector + 116
# 63  Python                              0x000000010506dc58 pymain_run_module + 208
# 64  Python                              0x000000010506d76c Py_RunMain + 896
# 65  Python                              0x000000010506eb58 Py_BytesMain + 40
# 66  dyld                                0x000000019641fe50 start + 2544
